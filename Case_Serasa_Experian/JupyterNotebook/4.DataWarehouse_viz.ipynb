# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
from pyspark.sql import functions as F
from pyspark.sql.types import *

sc = SparkContext.getOrCreate()
spark = SparkSession.builder.getOrCreate()
sqlContext = SQLContext(sc)

# %%
layer = 1
table = "tweets"
path = f"D:/layer{layer}/{table}/"
tweets = spark.read.parquet(path)
tweets.toPandas()
# Out:
#                 tweet_id                      created_at  \
# 0    1359019286451355648  Tue Feb 09 06:00:21 +0000 2021
# 1    1359018508676390925  Tue Feb 09 05:57:16 +0000 2021
# 2    1359018299468709889  Tue Feb 09 05:56:26 +0000 2021
# 3    1359018582970138628  Tue Feb 09 05:57:34 +0000 2021
# 4    1359018108778905600  Tue Feb 09 05:55:41 +0000 2021
# ..                   ...                             ...
# 110  1359018272063033344  Tue Feb 09 05:56:20 +0000 2021
# 111  1359019452575215618  Tue Feb 09 06:01:01 +0000 2021
# 112  1359019459470630913  Tue Feb 09 06:01:03 +0000 2021
# 113  1359018032895524865  Tue Feb 09 05:55:23 +0000 2021
# 114  1359018057247707137  Tue Feb 09 05:55:28 +0000 2021
#
#                                                   text             hashtags  \
# 0    Os Emirados Árabes Unidos (#EAU)restringem tem...                EAU,
# 1    Existem duas pandemias: a nossa contra a COVID...              bbb21,
# 2    RT @C11Bras_2: Coerente o tweet?\n\nSeriado de...
# 3    GloboLixo tem que EXPULSAR essa PSICOPATA!\n E...  DeusProtejeiTodos,
# 4    RT @carmelonetobr: Camilo Santana gastou R$547...
# ..                                                 ...                  ...
# 110                            Bravo #PolriDonorPlasma   PolriDonorPlasma,
# 111  @flaayoficial Quando essa mulher sair todos vã...
# 112  RT @caixaodepinus: imagina ser um neozelandes ...
# 113  RT @carmelonetobr: Camilo Santana gastou R$547...
# 114  RT @_Tiago666_: Apesar do covid o verao passad...
#
#      retweet_count possibly_sensitive lang              user_id  \
# 0                0              False   pt  1097962829276164097
# 1                0               None   pt  1045508615472336896
# 2                0               None   pt           1612672524
# 3                0              False   pt  1358920215409623041
# 4                0               None   pt  1010993359564034048
# ..             ...                ...  ...                  ...
# 110              0               None   pt  1270213562145763328
# 111              0               None   pt  1318332026571923458
# 112              0               None   pt            144570814
# 113              0               None   pt  1243597919925735429
# 114              0               None   pt  1163849121842847747
#
#                   user_name  \
# 0        Monitor do Oriente
# 1    Life is short, so Am I
# 2             Ricardo David
# 3          Sammarina Curado
# 4             Ronaldo Lopes
# ..                      ...
# 110                 Brigade
# 111                      Gi
# 112                  vic R1
# 113            Jorge Rached
# 114                  Gerson
#
#                                       user_description  user_verification  \
# 0    O Monitor do Oriente Médio (MEMO) é uma instit...              False
# 1                                                 None              False
# 2    #DireitaUnida\nNA LISTA MEU NOME APARECE? SIGA...              False
# 3                        Sinceridade mostra o CARÁTER!              False
# 4                                                 None              False
# ..                                                 ...                ...
# 110                                     tetap semangat              False
# 111                                               None              False
# 112                                               None              False
# 113                                               None              False
# 114                                               None              False
#
#      user_followers_count  user_friends_count                 user_created_at  \
# 0                     636                  16  Tue Feb 19 20:55:12 +0000 2019
# 1                     996                 143  Fri Sep 28 03:00:53 +0000 2018
# 2                      59                 135  Mon Jul 22 12:07:14 +0000 2013
# 3                       1                  86  Mon Feb 08 23:27:21 +0000 2021
# 4                      26                 467  Sun Jun 24 21:09:35 +0000 2018
# ..                    ...                 ...                             ...
# 110                     6                   6  Tue Jun 09 04:38:42 +0000 2020
# 111                     5                  54  Mon Oct 19 23:24:06 +0000 2020
# 112                   145                 189  Sun May 16 17:51:55 +0000 2010
# 113                   398                 500  Fri Mar 27 17:57:19 +0000 2020
# 114                    67                  50  Tue Aug 20 16:23:59 +0000 2019
#
#                    user_location                etl_load  \
# 0                         Brazil 2021-02-09 03:00:55.592
# 1         Rio de Janeiro, Brasil 2021-02-09 02:57:27.659
# 2                           None 2021-02-09 02:57:27.659
# 3                           None 2021-02-09 02:58:37.574
# 4    São José dos Campos, Brasil 2021-02-09 02:56:18.498
# ..                           ...                     ...
# 110                         None 2021-02-09 02:57:27.659
# 111                         None 2021-02-09 03:02:06.364
# 112                      Brasil  2021-02-09 03:02:06.364
# 113                         None 2021-02-09 02:56:18.498
# 114                         None 2021-02-09 02:56:18.498
#
#      etl_load_partition_year  etl_load_partition_month  \
# 0                       2021                         2
# 1                       2021                         2
# 2                       2021                         2
# 3                       2021                         2
# 4                       2021                         2
# ..                       ...                       ...
# 110                     2021                         2
# 111                     2021                         2
# 112                     2021                         2
# 113                     2021                         2
# 114                     2021                         2
#
#      etl_load_partition_day  etl_load_partition_hour
# 0                         9                        3
# 1                         9                        2
# 2                         9                        2
# 3                         9                        2
# 4                         9                        2
# ..                      ...                      ...
# 110                       9                        2
# 111                       9                        3
# 112                       9                        3
# 113                       9                        2
# 114                       9                        2
#
# [115 rows x 20 columns]

# %%
layer = 2
table = "fact_tweet"
path = f"D:/layer{layer}/{table}/"
fact_tweet = spark.read.parquet(path)
fact_tweet.toPandas()
# Out:
#                tweet_id          created_at  \
# 0   1359018508676390925 2021-02-09 02:57:16
# 1   1359018272063033344 2021-02-09 02:56:20
# 2   1359017482091167746 2021-02-09 02:53:11
# 3   1359018582970138628 2021-02-09 02:57:34
# 4   1359018243713880065 2021-02-09 02:56:13
# ..                  ...                 ...
# 75  1359018894233653249 2021-02-09 02:58:48
# 76  1359018315931262979 2021-02-09 02:56:30
# 77  1359018370499231745 2021-02-09 02:56:43
# 78  1359018032895524865 2021-02-09 02:55:23
# 79  1359018057247707137 2021-02-09 02:55:28
#
#                                                  text           hashtags  \
# 0   Existem duas pandemias: a nossa contra a COVID...              bbb21
# 1                             Bravo #PolriDonorPlasma   PolriDonorPlasma
# 2                                  Amores do #Fascism            Fascism
# 3   GloboLixo tem que EXPULSAR essa PSICOPATA!\n E...  DeusProtejeiTodos
# 4   obrigada boninho vc conseguiu nos dar o pior e...              BBB21
# ..                                                ...                ...
# 75  RT @MarceloFreixo: O gênio da logística deixou...               None
# 76  RT @FotosDeFatos: Na manhã de hoje, a Sra. Pol...               None
# 77  não acredito que vou morrer sem saber se essa ...               None
# 78  RT @carmelonetobr: Camilo Santana gastou R$547...               None
# 79  RT @_Tiago666_: Apesar do covid o verao passad...               None
#
#     retweet_count possibly_sensitive lang              user_id  \
# 0               0               None   pt  1045508615472336896
# 1               0               None   pt  1270213562145763328
# 2               0               None   pt            406766589
# 3               0              False   pt  1358920215409623041
# 4               0               None   pt  1265667918043504641
# ..            ...                ...  ...                  ...
# 75              0               None   pt             28701367
# 76              0               None   pt  1120423731199975425
# 77              0               None   pt  1339770399261913088
# 78              0               None   pt  1243597919925735429
# 79              0               None   pt  1163849121842847747
#
#     created_at_partition_year  created_at_partition_month  \
# 0                        2021                           2
# 1                        2021                           2
# 2                        2021                           2
# 3                        2021                           2
# 4                        2021                           2
# ..                        ...                         ...
# 75                       2021                           2
# 76                       2021                           2
# 77                       2021                           2
# 78                       2021                           2
# 79                       2021                           2
#
#     created_at_partition_day  created_at_partition_hour
# 0                          9                          2
# 1                          9                          2
# 2                          9                          2
# 3                          9                          2
# 4                          9                          2
# ..                       ...                        ...
# 75                         9                          2
# 76                         9                          2
# 77                         9                          2
# 78                         9                          2
# 79                         9                          2
#
# [80 rows x 12 columns]

# %%
layer = 2
table = "dim_user"
path = f"D:/layer{layer}/{table}/"
dim_user = spark.read.parquet(path)
dim_user.toPandas()
# Out:
#                 user_id                                          user_name  \
# 0              20913287                                        Jorge Roriz
# 1   1139206374443880448  Sublata causa, tollitur effectus #EleiçõesGera...
# 2             137311882                                               Rafa
# 3   1299071857145061376                              desligitimação do BBB
# 4    832338993635323904                              🇧🇷Thiago 🇧🇷😎 👉👉3️⃣8️⃣
# ..                  ...                                                ...
# 75  1120423731199975425                                        Paulo Borba
# 76  1339770399261913088                                               alex
# 77  1270213562145763328                                            Brigade
# 78  1243597919925735429                                       Jorge Rached
# 79  1163849121842847747                                             Gerson
#
#                                      user_description  user_verification  \
# 0   Jornalista graduado em ciência da comunicação....              False
# 1   Funcionário de estatal, neste tempo de trevas ...              False
# 2                                               Teemo              False
# 3                                                None              False
# 4   Neto do @JoaquinTeixeira  \nCidadão do Mundo.....              False
# ..                                                ...                ...
# 75                                            it's me              False
# 76                                           @b7xjj 💍              False
# 77                                     tetap semangat              False
# 78                                               None              False
# 79                                               None              False
#
#     user_followers_count  user_friends_count     user_created_at  \
# 0                   2529                2658 2009-02-15 11:48:25
# 1                    693                1048 2019-06-13 13:22:19
# 2                     90                 279 2010-04-26 09:10:17
# 3                      9                 357 2020-08-27 16:50:52
# 4                   2373                1157 2017-02-16 18:20:54
# ..                   ...                 ...                 ...
# 75                    19                 508 2019-04-22 17:26:48
# 76                   228                 204 2020-12-18 00:12:22
# 77                     6                   6 2020-06-09 01:38:42
# 78                   398                 500 2020-03-27 14:57:19
# 79                    67                  50 2019-08-20 13:23:59
#
#                      user_location
# 0                     Salvador- BA
# 1      Indeterminada, por enquanto
# 2                   Rio de Janeiro
# 3                   Ilhéus, Brasil
# 4                            Vênus
# ..                             ...
# 75  New Westminster, British Colum
# 76                     ruani dora
# 77                            None
# 78                            None
# 79                            None
#
# [80 rows x 8 columns]
