# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 9</font>
#
# ## Download: http://github.com/dsacademybr
#
# ## Mini-Projeto 2 - Análise Exploratória em Conjunto de Dados do Kaggle
#
# ## Análise 1

# %%
# %%markdown
# # https://www.kaggle.com/orgesleka/used-cars-database
# Out:
# # https://www.kaggle.com/orgesleka/used-cars-database

# %%
# Imports
import os
import subprocess
import stat
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
sns.set(style="white")
# %matplotlib inline

# %%
# Dataset
clean_data_path = "dataset/autos.csv"
df = pd.read_csv(clean_data_path,encoding="latin-1")

# %%
df.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat     Offer
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat     Offer
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat     Offer
# 3  2016-03-17 16:54:04             GOLF_4_1_4__3TÃRER  privat     Offer
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat     Offer
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  ...  \
# 0    480   test       Other                1993    manuell        0  ...
# 1  18300   test       coupe                2011    manuell      190  ...
# 2   9800   test         suv                2004  automatik      163  ...
# 3   1500   test  kleinwagen                2001    manuell       75  ...
# 4   3600   test  kleinwagen                2008    manuell       69  ...
#
#   postalCode             lastSeen yearOfCreation yearCrawled monthOfCreation  \
# ...

# %% [markdown]
# ## Distribuição de Veículos com base no Ano de Registro

# %%
# Crie um Plot com a Distribuição de Veículos com base no Ano de Registro

# %%
# Salvando o plot
# fig.savefig("plots/Analise1/vehicle-distribution.png")

# %%
fig = plt.figure(figsize=(10,7))
sns.distplot(df["yearOfRegistration"], color="g")
plt.title("Distribuição de veículos com base no ano de registro", fontsize=15)
plt.xlabel("Ano de Registro", fontsize=15)
plt.ylabel("Densidade (KDE)", fontsize=15)
# Out:
# Text(0, 0.5, 'Densidade (KDE)')

# %%
fig.savefig("plots/Analise1/vehicle-distribution_resolution.png")

# %% [markdown]
# ## Variação da faixa de preço pelo tipo de veículo

# %%
# Crie um Boxplot para avaliar os outliers

# %%
# Salvando o plot
# fig.savefig("plots/Analise1/price-vehicleType-boxplot.png")

# %%
fig = plt.figure(figsize=(10,7))
sns.boxplot(x=df["vehicleType"], y=df["price"])
plt.title("Análise de Outliers", fontsize=15)
plt.xlabel("Tipo de Veículo", fontsize=15)
plt.ylabel("Range de Preço", fontsize=15)
# Out:
# Text(0, 0.5, 'Range de Preço')

# %%
fig.savefig("plots/Analise1/price-vehicleType-boxplot_resolution.png")

# %% [markdown]
# ## Contagem total de veículos à venda conforme o tipo de veículo

# %%
# Crie um Count Plot que mostre o número de veículos pertencentes a cada categoria

# %%
# Salvando o plot
# g.savefig("plots/Analise1/count-vehicleType.png")

# %%
fig = plt.figure(figsize=(10,7))
sns.countplot(data=df, x="vehicleType", palette="Purples")
plt.title("Contagem total de veículos à venda conforme o tipo de veículo", fontsize=18)
plt.ylabel("Total de veículos para Venda", fontsize=15)
plt.xlabel("Tipo de Veículo", fontsize=15)
# Out:
# Text(0.5, 0, 'Tipo de Veículo')

# %%
fig.savefig("plots/Analise1/count-vehicleType_resolution.png")

# %% [markdown]
# Conheça a Formação Cientista de Dados, um programa completo, 100% online e 100% em português, com 340 horas, mais de 1.200 aulas em vídeos e 26 projetos, que vão ajudá-lo a se tornar um dos profissionais mais cobiçados do mercado de análise de dados. Clique no link abaixo, faça sua inscrição, comece hoje mesmo e aumente sua empregabilidade:
#
# https://www.datascienceacademy.com.br/pages/formacao-cientista-de-dados

# %% [markdown]
# # Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href="http://facebook.com/dsacademybr">facebook.com/dsacademybr</a>
