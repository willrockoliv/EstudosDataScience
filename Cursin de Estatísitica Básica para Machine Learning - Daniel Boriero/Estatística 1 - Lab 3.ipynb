#         35.47562689,  52.41618379,  11.19331298,  61.00900201,
#         31.81722827,  38.0725919 ,  27.36705979,  33.04054026,
#         43.70727495,  42.01658682,  36.28398933,   1.09611326,
#         25.0502938 ,  31.43678602,  23.784621  ,  76.01007017,
#         42.18909215,  53.84712375,  37.061197  ,  46.6579634 ,
#         39.44354099,  33.61449611,  32.42887336,  42.00891208,
#         31.22958968,  25.29658287,  70.74518233,  30.05197525,
#         52.19094774,  40.6143889 ,  26.05672938,  27.96605823,
#         39.40694267,  53.00102786,  28.64920914,  41.4524316 ,
#         32.46958135,  55.4892548 ,  34.95803997,  34.16706347,
#         31.9074474 ,  66.39112386,  44.96813865,  44.40739062,
#         40.10137132,  42.46374993,  57.62490167,  33.50523968,
#         17.81649574,  37.27009266,  50.51626848,  78.9109728 ,
#         25.78548626,  60.8577235 ,  73.08480761,  20.68785922,
#         31.00834091,  36.4611568 ,  43.51924415,  52.17851218,
#         59.47895844,  33.55921705,  60.54975265,  51.06619049,
#         42.14870985,  52.56397419,  50.54744404,   2.70791048,
#         31.19694312,  28.3645121 ,  32.48710055,  49.42731403,
#         24.04968759,  46.0209685 ,  43.80944024,  41.15028135,
#         42.26490857,  24.49188075,  41.73212948,  31.25912049,
#         32.30379765,  25.25550964,  59.42343545,  42.90373961,
#         46.50795109,  54.86133434,  36.24348942,  26.69284299,
#         62.08322904,  19.18287535,  31.41925322,  49.55794128,
#         58.18720161,  42.95023775,  24.96453834,  53.06342627,
#         44.64083155,  15.01175056,  55.98993629,  54.38774021,
#         46.95239364,  29.43114217,  21.44300111,  47.4958465 ,
#         36.45025197,  38.07081972,  52.28592667,  48.57526759,
#         19.36042579,  46.42007505,  22.18985905,  67.77354568,
#         14.59307025,  30.84491364,  41.8837715 ,  29.36327619,
#         48.00247603,  51.80465725,  50.54360501,  25.62773948,
#         49.39204894,  56.31300385,  56.99509657,  64.11167755,
#         31.0429267 ,  28.94983165,  28.5887058 ,  44.20689745,
#         10.13926908,  43.05445394,  23.4482263 ,  52.47670252,
#         37.14604255,  43.58769667,  21.94226612,  29.42207795,
#         13.80024063,  27.97223163,  47.18921021,  56.49281959,
#         12.25390168,  34.69182905,  20.8460107 ,  40.38107777,
#         53.19925263,  47.14880104,  35.33

# %%
#Plote a PDF e a CDF, do vetor criado, juntos utilizando "hist" mas o segundo em um eixo diferente
#dica: -veja o exemplo de dois gráficos em uma mesma imagem com eixos diferentes
#      -veja os parâmetros cumulative e density

# %%
import matplotlib.pyplot as plt
f, ax1 = plt.subplots(figsize=(8, 4))

ax1.hist(X, density=True,color='blue', bins=30)

ax1_twin = ax1.twinx()

ax1_twin.hist(X, density=True, color='red', cumulative=True, linewidth=2, histtype='step', bins=30)

display(f)

# %%
# Calcule os percentis da distribuição original para as seguintes porcentagens:
# 5%, 25%, 75%, 95%
#dica: -ordene o vetor com "sorted" e conte o número de itens com "len"

# %%
X_sorted = sorted(X)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# pegando os percentis
(X_sorted[int(0.05*len(X_sorted))],X_sorted[int(0.25*len(X_sorted))],X_sorted[int(0.75*len(X_sorted))],X_sorted[int(0.95*len(X_sorted))])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: (14.404992046542915, 29.20857028689983, 49.52565704543391, 62.51679727830149)</div>

# %%
#Faça o mesmo, mas com a função percentile da biblioteca numpy
import numpy as np
np.percentile(X,[5, 25, 75, 95])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: array([14.40496524, 29.19299861, 49.51378957, 62.48806902])</div>

# %%
#Encontre os valores que delimitam o percentil de 68.3% em torno da média
#
#dica: -pode considerar que a distribuição é simétrica em torno da média, ou seja a média é igual à mediana e percentuais distribuim-se
#       simetricamente em torno dela

print( 68.3 / 2 )

mean = np.mean(X)
print(mean)

median = np.median(X)
print(median)

stddev =  np.std(X)
print(stddev)

percentis = (X_sorted[int((len(X_sorted)/2) - 0.3415*len(X_sorted))], X_sorted[int((len(X_sorted)/2) + 0.3415*len(X_sorted))])
print(percentis)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">34.15
# 39.20741089321563
# 39.31699076575858
# 14.938323517816391
# (24.852237413954704, 53.84094242159594)
# </div>

# %%
#Faça o mesmo para 95% 
print(95/2)

percentis = (X_sorted[int((len(X_sorted)/2) - 0.475*len(X_sorted))], X_sorted[int((len(X_sorted)/2) + 0.475*len(X_sorted))])
print(percentis)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">47.5
# (10.125737421754586, 68.02847180641764)
# </div>

# %%
#Verifique a coincidência do intervalor de 68.3% com o desvio padrão e o porquê o chamam de 1sigma, e o de 95% com 2sigma

# %%
(np.mean(X)-np.std(X), np.mean(X)+np.std(X))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[32]: (24.269087375399238, 54.145734411032024)</div>

# %%
(np.mean(X)-2*np.std(X), np.mean(X)+2*np.std(X))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[33]: (9.330763857582848, 69.08405792884841)</div>

# %%
#Utilize a função norm.interval da biblioteca scipy.stats pra confirmar que para uma distribuição normal, os intervalos de confianção
#são os obtidos de forma manual para 68.3% e para 95%

#dica: scipy.stats.norm.interval(cl,loc=mean,scale=stddev)

import scipy.stats as st
st.norm.interval(0.95, 7000, 3000)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: (1120.108046379838, 12879.891953620161)</div>

# %%
#Plot a PDF e a CDF da distribuição novamente, juntamente com retas verticais que delimitem a região de 1sigma e de 2sigma e com legendas
#
#dica:  -use ax1.axvline(pos_x, pos_y_inicial, pos_y_final, color='black', label='teste')

# %%
import matplotlib.pyplot as plt
f, ax1 = plt.subplots(figsize=(8, 4))

ax1.hist(X, density=True,color='blue', bins=30)

ax1_twin = ax1.twinx()

ax1_twin.hist(X, density=True, color='red', cumulative=True, linewidth=2, histtype='step', bins=30)

ax1.axvline(40, 0, 1, color='red', label='median')

ax1.axvline(24, 0, 1, color='black', label='1sigma')
ax1.axvline(54, 0, 1, color='black')

ax1.axvline(9, 0, 1, color='black', linestyle='--', label='2sigma')
ax1.axvline(69, 0, 1, color='black', linestyle='--')

ax1.legend()

display(f)
