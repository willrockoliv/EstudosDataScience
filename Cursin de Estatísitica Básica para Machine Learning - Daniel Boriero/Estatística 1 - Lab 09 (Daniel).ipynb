# %%
#Crie dois vetores com 5000 números aleatórios, os dois distribuídos gaussianamente. Observe que nesse exemplo, cada posição no vetor correspondente a uma mesma pessoa.
# 1. o primeiro com centro em 36 e desvio padrão de 4, o qual suporemos que é uma distribuição de idade
# 2. o segundo com centro em 7000 e desvio padrão de 1000, o qual suporemos que é uma distribuição de renda

# dicas: - pode utilizar os métodos rvs das funções na biblioteca stat da scipy
#        - https://docs.scipy.org/doc/scipy/reference/stats.html

import scipy.stats as st

exemplo1 = st.norm.rvs(loc=1000, scale=10, size=1000, random_state=None)
exemplo2 = st.norm.rvs(loc=1000, scale=10, size=1000, random_state=None)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import scipy.stats as st

idade = st.norm.rvs(loc=36, scale=4, size=5000, random_state=None)
renda = st.norm.rvs(loc=7000, scale=1000, size=5000, random_state=None)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Transforme as duas distribuições em distrições de zscore e as plote em histogramas
# dicas: - utilize o método zscore da bibliteca scipy.stats

import matplotlib.pyplot as plt

zexemplo1 = st.zscore(exemplo1)
zexemplo2 = st.zscore(exemplo2)

f, (ax1,ax2) = plt.subplots(2,1,figsize=(8, 8))

ax1.hist(zexemplo1,density=True)
ax1.set_xlabel('Frequência')
ax1.set_ylabel('Z_exemplo')

ax2.hist(zexemplo2,density=True)
ax2.set_xlabel('Frequência')
ax2.set_ylabel('Z_exemplo')

f.tight_layout()
display(f)

# %%
zidade = st.zscore(idade)
zrenda = st.zscore(renda)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import matplotlib.pyplot as plt
import scipy.stats as st


f, (ax1,ax2) = plt.subplots(2,1,figsize=(8, 8))

ax1.hist(zidade,density=True)
ax1.set_ylabel('Frequência')
ax1.set_xlabel('Z_idade')

ax2.hist(zrenda,density=True)
ax2.set_ylabel('Frequência')
ax2.set_xlabel('Z_renda')

f.tight_layout()
display(f)

# %%
#Plote o espalhamento dessas duas variáveis originais (e não do zscore)
#
#
#dica: -use o plot "scatter", utilize o parâmetro "alpha" para ter um senso de densidade
#       https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.scatter.html  

import matplotlib.pyplot as plt

f, ax1 = plt.subplots(figsize=(8, 8))

ax1.scatter(exemplo1,exemplo2, alpha=0.3)
ax1.set_xlabel('Exemplo')
ax1.set_ylabel('Exemplo')


f.tight_layout()
display(f)

# %%
import matplotlib.pyplot as plt

f, ax1 = plt.subplots(figsize=(6, 6))

ax1.scatter(idade,renda, alpha=0.2)
ax1.set_xlabel('idade')
ax1.set_ylabel('renda')


f.tight_layout()
display(f)

# %%
#Plote o espalhamento em formato hexagonal binado dessas duas variáveis, mas agora utilizando o zscore de cada
#
#
#dica: -use o plot "scatter", utilize o parâmetro "cmap" para ter um senso de densidade com diferentes esquemas de cores
#       https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hexbin.html

import matplotlib.pyplot as plt

f, ax1 = plt.subplots(figsize=(8, 6))

hb= ax1.hexbin(zexemplo1,zexemplo2, gridsize=25,cmap='terrain_r')
ax1.set_xlabel('Exemplo')
ax1.set_ylabel('Exemplo')

f.colorbar(hb, ax=ax1)

f.tight_layout()
display(f)

# %%
import matplotlib.pyplot as plt

f, ax1 = plt.subplots(figsize=(8, 6))

hb=ax1.hexbin(zidade,zrenda, cmap='coolwarm', gridsize=25)
ax1.set_xlabel('z_idade')
ax1.set_ylabel('z_renda')

f.colorbar(hb, ax=ax1)

f.tight_layout()
display(f)

# %%
'teste' is not a valid value for name; supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r'

# %%
original = [1,1,2,2,2,3,3,4]

x_original = [1,2,3,4]
y_original = [2,3,2,1]

# %%
#Não há no python gráficos que plotem distribuições em 3D e curvas de níveis, portanto é necessário transformar as duas distribuições em um sistema de três variáveis,
#para isso é possível usar o método "histogram" para uma variável ou "histogram2d" para duas variáveis da biblioteca numpy, faça-o já utilizando o equivalente em zscore
#
#dica:  -veja a documentação
#        https://docs.scipy.org/doc/numpy/reference/generated/numpy.histogram2d.html

import numpy as np
(z_frequency, x_bins, y_bins) = np.histogram2d(zexemplo1,zexemplo2,bins=20)
x_bins = [(x+x_bins[i-1+1])/2 for i,x in enumerate(x_bins[1:])]
y_bins = [(x+y_bins[i-1+1])/2 for i,x in enumerate(y_bins[1:])]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import numpy as np
(z_frequency, x_bins, y_bins) = np.histogram2d(zidade,zrenda)
x_bins = [(x+x_bins[i-1+1])/2 for i,x in enumerate(x_bins[1:])]
y_bins = [(x+y_bins[i-1+1])/2 for i,x in enumerate(y_bins[1:])]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#A partir das relações entre as distribuições em zscore e sua frequência, plote um espalhamento com curvas de nível do zscore da sua frequência
#
#dica:  -utilize o gráfico "contour" mas agora informando a terceira dimensão, Z
#        https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.contour.html
#        https://matplotlib.org/3.1.1/gallery/images_contours_and_fields/contour_demo.html#sphx-glr-gallery-images-contours-and-fields-contour-demo-py

import matplotlib.pyplot as plt

f, ax1 = plt.subplots(figsize=(6, 4))

cs = ax1.contour(x_bins,y_bins, z_frequency, 4, cmap='inferno')
ax1.set_xlabel('Idade')
ax1.set_ylabel('Renda')

ax1.clabel(cs, inline=1, fontsize=10, fmt='%1.0f')


f.tight_layout()
display(f)

# %%
import matplotlib.pyplot as plt

f, ax1 = plt.subplots(figsize=(6, 4))

cs = ax1.contour(x_bins,y_bins, z_frequency, 4, cmap='coolwarm')
ax1.set_xlabel('Z_idade')
ax1.set_ylabel('Z_renda')

ax1.clabel(cs, inline=1, fontsize=10, fmt='%1.0f')


f.tight_layout()
display(f)

# %%
#Faça o mesmo plote do acima mas agora com o percentil da sua frequência e os intervalos de 68.3% e 95% em torno da moda, por último combine-o com o hexbin scatterplot
#
#dica:  -utilize o gráfico "contour" mas agora informando a terceira dimensão, o rankeamente de percentil
#        https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.contour.html
#        https://matplotlib.org/3.1.1/gallery/images_contours_and_fields/contour_demo.html#sphx-glr-gallery-images-contours-and-fields-contour-demo-py
#
#        -Não encontrei como fazer o zscore de uma frequência já computada, e portanto em função do máximo, então fiz manualmetne como no exemplo abaixo

z_frequency_score = [[100*np.sum([[y1 if y1>y else 0 for y1 in x1] for x1 in z_frequency])/np.sum(z_frequency) for y in x] for x in z_frequency] 

import matplotlib.pyplot as plt
import scipy.stats as st

f, ax1 = plt.subplots(figsize=(6, 4))

hb= ax1.hexbin(zexemplo1,zexemplo2, cmap='Greens', gridsize=25, alpha=0.75)
cs = ax1.contour(x_bins,y_bins, z_frequency_score, [68.3,95], colors='black', linestyles =['solid','dashed'], linewidths =[2,1])
ax1.set_xlabel('exemplo1')
ax1.set_ylabel('exemplo2')

ax1.clabel(cs, inline=1, fontsize=10, fmt='%1.1f%%')
f.colorbar(hb, ax=ax1)



f.tight_layout()
display(f)

# %%
z_frequency_score = [[100*np.sum([[y1 if y1>y else 0 for y1 in x1] for x1 in z_frequency])/np.sum(z_frequency) for y in x] for x in z_frequency] 

import matplotlib.pyplot as plt
import scipy.stats as st

f, ax1 = plt.subplots(figsize=(6, 4))

hb= ax1.hexbin(zidade,zrenda, cmap='Greens', gridsize=25, alpha=1)
cs = ax1.contour(x_bins,y_bins, z_frequency_score, [68.3,95], colors='black', linestyles =['solid','dashed'], linewidths =[2,1])
ax1.set_xlabel('Z_Idade')
ax1.set_ylabel('Z_Renda')

ax1.clabel(cs, inline=1, fontsize=10, fmt='%1.1f%%')
f.colorbar(hb, ax=ax1)


f.tight_layout()
display(f)

# %%
#Há alguma correlação aparente nesse espalhamento?

#NO
